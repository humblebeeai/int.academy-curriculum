# %% [markdown]
# Soft Landing ResourceCard pattern:\n- Fields: type, title, url, duration, difficulty, why\n- Difficulty scale: easy, intermediate, advanced\n- Tone: concise, practical, aligned with Math-ML examples.
